# %% [markdown]
# **In this kernel, We will analyze the video game sales. First of all, we would like to examine the most sold 100 gam**es in the global perspective

# %% [markdown]
# importing the libraries

# %%
import pandas as pd # for dataframe 
import seaborn as sns #for plotting and finding the relationship between the dataframe 
import matplotlib.pyplot as plt

# %% [markdown]
# accessing the csv dataset in a dataframe

# %%
df=pd.read_csv('/content/vgsales.csv')
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# In this data set there are 11 columns. Their names and data types as follows:
#
# Rank - Ranking of overall sales, integer
#
# Name - The games name, object
#
# Platform - Platform of the games release (i.e. PC,PS4, etc.), object
#
# Year - Year of the game's release, float
#
# Genre - Genre of the game ,object
#
# Publisher - Publisher of the game
#
# NA_Sales - Sales in North America (in millions)
#
# EU_Sales - Sales in Europe (in millions)
#
# JP_Sales - Sales in Japan (in millions)
#
# Other_Sales - Sales in the rest of the world (in millions)
#
# Global_Sales - Total worldwide sales.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# The info() function is used to print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage

# %%
df.describe()
# Out:
#                Rank          Year  ...   Other_Sales  Global_Sales
# count  16598.000000  16327.000000  ...  16598.000000  16598.000000
# mean    8300.605254   2006.406443  ...      0.048063      0.537441
# std     4791.853933      5.828981  ...      0.188588      1.555028
# min        1.000000   1980.000000  ...      0.000000      0.010000
# 25%     4151.250000   2003.000000  ...      0.000000      0.060000
# 50%     8300.500000   2007.000000  ...      0.010000      0.170000
# 75%    12449.750000   2010.000000  ...      0.040000      0.470000
# max    16600.000000   2020.000000  ...     10.570000     82.740000
#
# [8 rows x 7 columns]

# %% [markdown]
# The describe() method is used for calculating some statistical data like count,percentile, mean and std and percentile of the Series or DataFrame.

# %% [markdown]
# # Top 100 Video Games

# %%
df.head(100)
#The table below shows the sales of the top 100 games according to different regions
# Out:
#     Rank                                    Name  ... Other_Sales  Global_Sales
# 0      1                              Wii Sports  ...        8.46         82.74
# 1      2                       Super Mario Bros.  ...        0.77         40.24
# 2      3                          Mario Kart Wii  ...        3.31         35.82
# 3      4                       Wii Sports Resort  ...        2.96         33.00
# 4      5                Pokemon Red/Pokemon Blue  ...        1.00         31.37
# ..   ...                                     ...  ...         ...           ...
# 95    96  Crash Bandicoot 2: Cortex Strikes Back  ...        0.31          7.58
# 96    97                     Super Mario Bros. 2  ...        0.19          7.46
# 97    98     Super Smash Bros. for Wii U and 3DS  ...        0.43          7.45
# 98    99              Call of Duty: World at War  ...        0.69          7.37
# 99   100                           Battlefield 3  ...        0.69          7.34
#
# ...

# %% [markdown]
# At this point, Wii sports takes the first place and especially the sales in the North America. Wii Sports is a sports video game developed and published by Nintendo for the Wii video game console. The game was released in North America along with the Wii on November 19, 2006, and was released in Japan, Australia, and Europe the following month.The game is a collection of five sports simulations, designed to demonstrate the motion-sensing capabilities of the Wii Remote. The five sports included are tennis, baseball, bowling, golf and boxing.![Wiisports.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Second place is Super Mario Bros. It is a platform video game developed and published by Nintendo. The successor to the 1983 arcade game, Mario Bros., it was released in Japan in 1985 for the Famicom, and in North America and Europe for the Nintendo Entertainment System (NES) in 1985 and 1987 respectively. Players control Mario, or his brother Luigi in the multiplayer mode, as they travel the Mushroom Kingdom to rescue Princess Toadstool from the antagonist, Bowser.![super-mario-660x371.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Other games rank as follows:
#
# 3- Mario Kart Wii,
#
# 4- Wii Sports Resort,
#
# 5- Pokemon Red / Pokemon Blue,
#
# 6- Tetris,
#
# 7- New Super Mario Bros,
#
# 8- Wii Play,
#
# 9- New Super Mario Bros Wii ,
#
# 10-Duck Hunt
#
# and so on...

# %% [markdown]
# Although North America and Europe sales in general have led to these rankings, we can see that GTA: San Andreas, ranked 18th, and Gran Turismo 4, 48th, sales in other regions are higher than sales in North America, Europe and Japan.
#
# Nintendogs ranked 11th, GTA 5,17th, Brain: Train Your Brain in Minutes a Day, 20th, Call of Duty: Black Ops II, 35th, Call of Duty: Modern Warfare 3, 38th, Gran Turismo 5,55th, FIFA 16,78th, FIFA Soccer 2013, 83rd, The Sims 3 ,84th, , and Star Wars Battlefront and Call of Duty: Advanced Warfare, 93th and 94th, games are the most sold in the European region.
#
# Also, In Japan, we can see Pokemon Black / Pokemon White ranked 27th , Animal Crossing: Wild World,42nd place, Final Fantasy VII ,67th, Animal Crossing: New Leaf , 74th, Super Mario Kart, 77th, Final Fantasy VIII ,88th, games were sold than other regions.
#
# Games other than those listed above were mostly sold in North America.

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
#  ## isna function is used for detecting missing values in the dataset,missing values get mapped to True and non missing value mapped to False.
# Above its showing that the datframe "Year" and "Publisher" having 271 and 58 missing values respectively.

# %%
df['Year']=df['Year'].fillna("U")
df['Publisher']=df['Publisher'].fillna("U")

# %% [markdown]
# ### fillna function used to fill NA/NAN using the specified method.fill the NAN value by "U"(called as unknown).

# %%
df.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# now all the missing values are filled.

# %%
sns.pairplot(df)

# %% [markdown]
# ### The pair plot is shown in above in the image.its using video game sale data set.measurements Global sales,other sales,JP sales,EU sales,Rank,NA sales.because of measurement sales provide excellent way to distinguish sales.

# %% [markdown]
# # Visualisation

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# It displays name of all the columns present in the dataframe
# and their datatypes

# %%
plt.figure(figsize=(10,7))
plt.scatter(data=df,x='Global_Sales',y='NA_Sales',marker="o")
plt.title('NA_Sales')
# Out:
# Text(0.5, 1.0, 'NA_Sales')

# %% [markdown]
# ### In this scatterd plot it can be observed that these columns and rows are suitable for linear regression.

# %%
plt.figure(figsize=(10,7))
plt.scatter(data=df,x='Global_Sales',y='EU_Sales',marker="o")
plt.title('EU_Sales')
# Out:
# Text(0.5, 1.0, 'EU_Sales')

# %% [markdown]
# ### In this scatterd plot it can be observed that these columns and rows are suitable for linear regression.

# %%
plt.figure(figsize=(10,7))
plt.scatter(data=df,x='Global_Sales',y='JP_Sales',marker="o")
plt.title('JP_Sales')
# Out:
# Text(0.5, 1.0, 'JP_Sales')

# %% [markdown]
# ##In this scatterd plot it can be observed that these columns and rows are suitable for linear regression.Scatter plot is used to identify a Linear relationship in X and Y. In regression analysis we can use scattred plot to visually inspect the data to see whether X and Y are linearly related.
# if the relationship displayed in scatterd plot is not linear you will have to either run nonlinear analysis ,perform a polynomial regression.

# %% [markdown]
# # Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
plt.figure(figsize=(10,7))
x=df[['NA_Sales']] #independant variable
y=df[['Global_Sales']] #dependant variable
model=LinearRegression()
model.fit(x,y) #fitting the data in linear regression model
ypred=model.predict(x)
plt.scatter(x,y)
plt.plot(x,ypred,color='r',marker='o')
model.score(x,y)
print("Y intercept=",model.intercept_)
print("slope=",model.coef_)
# Out:
# Y intercept= [0.06320234]
# slope= [[1.79182728]]

# %% [markdown]
# Linear regression needs the relationship between the independent and dependent variables to be linear. Let's use a pair plot to check the relation of independent variables with the Sales variable

# %%
plt.figure(figsize=(10,7))
x=df[['EU_Sales']]
y=df[['Global_Sales']]
model.fit(x,y)
ypred=model.predict(x)
plt.scatter(x,y)
plt.plot(x,ypred,color='r',marker='o')
model.score(x,y)
print("Y intercept=",model.intercept_)
print("slope=",model.coef_)
# Out:
# Y intercept= [0.1300213]
# slope= [[2.77813692]]

# %% [markdown]
# simple linear regression is a linear regression model with a single explanatory variable

# %%
plt.figure(figsize=(10,7))
x=df[['JP_Sales']]
y=df[['Global_Sales']]
model.fit(x,y)
ypred=model.predict(x)
plt.scatter(x,y)
plt.plot(x,ypred,color='r',marker='o')
model.score(x,y)
print("Y intercept=",model.intercept_)
print("slope=",model.coef_)
# Out:
# Y intercept= [0.2981812]
# slope= [[3.07603941]]

# %%
plt.figure(figsize=(10,7))
x=df[['Other_Sales']]
y=df[['Global_Sales']]
model.fit(x,y)
ypred=model.predict(x)
plt.scatter(x,y)
plt.plot(x,ypred,color='r',marker='o')
model.score(x,y)
print("Y intercept=",model.intercept_)
print("slope=",model.coef_)
# Out:
# Y intercept= [0.24087018]
# slope= [[6.17045032]]

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# importing Linear regression model

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
x=df[['NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales']]# multiple independant variables
y=df[['Global_Sales']]#Dependant variable
model.fit(x,y)
ypred=model.predict(x)
model.score(x,y)
# Out:
# 0.999988724759158

# %% [markdown]
# the accuracy of the prediction is 99%

# %% [markdown]
# importing train_test_split method...
# The train-test split procedure is used to estimate the performance of machine learning algorithms when they are used to make predictions on data not used to train the model.

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)
model=LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(xtest,ytest)
# Out:
# 0.9999810602588783

# %%
model.score(x,y)
# Out:
# 0.9999887242599866

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9999897620504768

# %%
ypred=model.predict(x)

# %%
sns.boxplot(data=df)

# %% [markdown]
# the black line in between the blue box defines the median.this type of graph used to removing the outlier.graph shows the shape of the distribution its central value and its verbality.
# box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles

# %%
df.shape
# Out:
# (16598, 11)

# %% [markdown]
# dimension of the dataframe....16598 rows and 11 columns

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# Rank            8298.50
# NA_Sales           0.24
# EU_Sales           0.11
# JP_Sales           0.04
# Other_Sales        0.04
# Global_Sales       0.41
# dtype: float64

# %% [markdown]
# Calculate Q1 ( the first Quarter)
# Calculate Q3 ( the third Quartile)
# Find IQR = (Q3 - Q1)
# Find the lower Range = Q1 -(1.5 * IQR)
# Find the upper Range = Q3 + (1.5 * IQR)
#
#
# The interquartile range (IQR) is the difference between the 75th and 25th percentile of the data

# %%
ndf=df[-((df<(Q1 - 1.5 * IQR)) | (df>(Q3 + 1.5 * IQR))).any(axis=1)]

# %%
sns.boxplot(data=ndf)

# %%
ndf.shape
# Out:
# (12018, 11)

# %% [markdown]
# shape after removing the outliers

# %%
x=ndf[['NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales']]
y=ndf[['Global_Sales']]
model.fit(x,y)
ypred=model.predict(xtest)
model.score(x,y)
# Out:
# 0.9990632151063293

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(x,y)
# Out:
# 0.9990632151063293

# %%
model.score(xtest,ytest)
# Out:
# 0.9989531353810851

# %% [markdown]
# ## Mean of Residuals

# %%
import numpy as np

ypred=model.predict(x)
res=y-ypred

res.mean()
# Out:
# Global_Sales   -2.084136e-17
# dtype: float64

# %% [markdown]
# Very close to zero so all good here.

# %% [markdown]
# ## Check for Normality of error terms/residuals

# %%
sns.histplot(res,kde=True)

# %% [markdown]
# The residual terms are pretty much normally distributed for the number of test points we took.
# Lets make it more smooth

# %% [markdown]
# ### A histogram is basically used to represent data in the form of some group.Bins are cleary identification as consecutive,non overlapping intervals of variable.using bar different hights.in histogram each bar groups numbers into ranges.Taller bars shoes that more data falls in that range.

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
mmodel=MinMaxScaler()
mmodel.fit(x)
xn=mmodel.transform(x)
xnorm=pd.DataFrame(xn)

# %%
mmodel.fit(y)
yn=mmodel.transform(y)
ynorm=pd.DataFrame(yn)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xnorm,ynorm,test_size=0.2)

# %%
model.fit(xnorm,ynorm)
 
ypred=model.predict(xtest)
model.score(xtrain,ytrain)
# Out:
# 0.9990657250287861

# %%
ypred=model.predict(xtest)
model.score(xtest,ytest)
# Out:
# 0.9990530270427481

# %%
import numpy as np

ypred=model.predict(x)
res=y-ypred

res.mean()
# Out:
# Global_Sales    0.096489
# dtype: float64

# %% [markdown]
# A residual is the vertical distance between a data point and the regression line. ... In other words, the residual is the error that isn't explained by the regression line
#
# Residuals in a statistical or machine learning model are the differences between observed and predicted values of data.

# %%
sns.histplot(res,kde=True)

# %% [markdown]
# Now the residual terms are pretty much normally distributed for the number of test points we took.A skew is also visible from the plot which is positive skew. It's very difficult to get perfect curves, distributions in real life data.

# %% [markdown]
# A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within discrete bins.

# %%
a = sns.distplot(res,kde=True)
a = plt.title('Normality of error terms/residuals')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The residual terms are pretty much normally distributed for the number of test points we took. Remember the central limit theorem which says that as the sample size increases the distribution tends to be normal. A skew is also visible from the plot. It's very difficult to get perfect curves, distributions in real life data.

# %% [markdown]
# ## No autocorrelation of residuals

# %% [markdown]
# Checking for autocorrelation To ensure the absence of autocorrelation we use Ljungbox test.
# Null Hypothesis: Autocorrelation is absent.
# Alternative Hypothesis: Autocorrelation is present.

# %%
from statsmodels.stats import diagnostic as diag
min(diag.acorr_ljungbox(res , lags = 40)[1])
# Out:
# 0.0

# %% [markdown]
# ### Since p value is less than 0.05 we reject the null hypothesis that error terms are not autocorrelated.

# %%
# autocorrelation
import statsmodels.api as sm

sm.graphics.tsa.plot_acf(res, lags=40)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## partial autocorrelation

# %%
# partial autocorrelation
sm.graphics.tsa.plot_pacf(res, lags=40)
plt.show()

# %%
plt.figure(figsize=(10,10))  # on this line I just set the size of figure to 12 by 10.
p=sns.heatmap(df.corr(), annot=True,square=True)  # seaborn has very simple solution for heatmap

# %% [markdown]
# Look for correlation of rows where the dependent variable (Sales in this case) is not involved because if a variable is correlated with the dependent variable then this would be a good sign for our model. Correlation within dependent variables is what we need to look for and avoid. This data doesn't contain perfect multicollinearity among independent variables. In case there was any then we would try to remove one of the correlated variables depending on which was more important to our regression model.

# %% [markdown]
# ###  Conclusion:Regression analysis a model that describe the relation between the dependent variable and independent variable in a simplified mathematical function will best describe such relationship or simple assumption have made that is the case by using linear regression.After the Linear Regression analysis of the Data we got the accuracy of the prediction is 99%. It shows the increment in accuracy of given dataset.
